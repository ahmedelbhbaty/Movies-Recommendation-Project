# %%
import pandas as pd 
import numpy as np 
import streamlit

# %%
movies_ds = pd.read_csv(r"C:\Users\elbhb\Desktop\Movies Recommendation Project\tmdb_5000_movies.csv")
credits_ds= pd.read_csv(r"C:\Users\elbhb\Desktop\Movies Recommendation Project\tmdb_5000_credits.csv")

# %%
movies_ds.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
credits_ds.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
movies_ds.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
credits_ds.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %%
credits_ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   movie_id  4803 non-null   int64
#  1   title     4803 non-null   object
#  2   cast      4803 non-null   object
#  3   crew      4803 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 150.2+ KB

# %%
credits_ds.shape
# Out:
# (4803, 4)

# %%
movies_ds.shape
# Out:
# (4803, 20)

# %%
movies_ds = movies_ds.merge(credits_ds , on='title')

# %%
movies_ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4809 entries, 0 to 4808
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4809 non-null   int64
#  1   genres                4809 non-null   object
#  2   homepage              1713 non-null   object
#  3   id                    4809 non-null   int64
#  4   keywords              4809 non-null   object
#  5   original_language     4809 non-null   object
#  6   original_title        4809 non-null   object
#  7   overview              4806 non-null   object
#  8   popularity            4809 non-null   float64
#  9   production_companies  4809 non-null   object
#  10  production_countries  4809 non-null   object
#  11  release_date          4808 non-null   object
#  12  revenue               4809 non-null   int64
#  13  runtime               4807 non-null   float64
#  14  spoken_languages      4809 non-null   object
# ...

# %%
movies_ds = movies_ds[['movie_id','title','overview','budget','genres','keywords','cast','crew']]

# %%
movies_ds.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview     budget  \
# 0  In the 22nd century, a paraplegic Marine is di...  237000000
# 1  Captain Barbossa, long believed to be dead, ha...  300000000
# 2  A cryptic message from Bond’s past sends him o...  245000000
# 3  Following the death of District Attorney Harve...  250000000
# 4  John Carter is a war-weary, former military ca...  260000000
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...

# %%
movies_ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4809 entries, 0 to 4808
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   movie_id  4809 non-null   int64
#  1   title     4809 non-null   object
#  2   overview  4806 non-null   object
#  3   budget    4809 non-null   int64
#  4   genres    4809 non-null   object
#  5   keywords  4809 non-null   object
#  6   cast      4809 non-null   object
#  7   crew      4809 non-null   object
# dtypes: int64(2), object(6)
# memory usage: 300.7+ KB

# %%
movies_ds.isnull().sum()
# Out:
# movie_id    0
# title       0
# overview    3
# budget      0
# genres      0
# keywords    0
# cast        0
# crew        0
# dtype: int64

# %%
movies_ds.dropna(inplace= True)

# %%
movies_ds.isnull().sum()
# Out:
# movie_id    0
# title       0
# overview    0
# budget      0
# genres      0
# keywords    0
# cast        0
# crew        0
# dtype: int64

# %%
movies_ds.duplicated().sum()
# Out:
# 0

# %%
movies_ds.iloc[0].genres
# Out:
# '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]'

# %%
import ast

def convert(obj):
    L=[]
    for i in ast.literal_eval(obj):
        L.append(i['name'])
    return L

# %%
movies_ds['genres'] = movies_ds['genres'].apply(convert)
movies_ds['keywords'] = movies_ds['keywords'].apply(convert)
movies_ds.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview     budget  \
# 0  In the 22nd century, a paraplegic Marine is di...  237000000
# 1  Captain Barbossa, long believed to be dead, ha...  300000000
# 2  A cryptic message from Bond’s past sends him o...  245000000
# 3  Following the death of District Attorney Harve...  250000000
# 4  John Carter is a war-weary, former military ca...  260000000
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# ...

# %%
import ast

def convert2(obj):
    L=[]
    counter = 0
    for i in ast.literal_eval(obj):
        if counter !=3:
            L.append(i['name'])
            counter +=1
        else: 
            break
        return L

# %%
movies_ds['cast'] = movies_ds['cast'].apply(convert2)

# %%
movies_ds.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview     budget  \
# 0  In the 22nd century, a paraplegic Marine is di...  237000000
# 1  Captain Barbossa, long believed to be dead, ha...  300000000
# 2  A cryptic message from Bond’s past sends him o...  245000000
# 3  Following the death of District Attorney Harve...  250000000
# 4  John Carter is a war-weary, former military ca...  260000000
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# ...

# %%
def fetch_director(obj):
    L=[]
    for i in ast.literal_eval(obj):
        if i['job'] == 'Director' :
            L.append(i['name'])
            break
    return L

# %%
movies_ds['crew'] = movies_ds['crew'].apply(fetch_director)

# %%
movies_ds.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview     budget  \
# 0  In the 22nd century, a paraplegic Marine is di...  237000000
# 1  Captain Barbossa, long believed to be dead, ha...  300000000
# 2  A cryptic message from Bond’s past sends him o...  245000000
# 3  Following the death of District Attorney Harve...  250000000
# 4  John Carter is a war-weary, former military ca...  260000000
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# ...

# %%
movies_ds['overview'][0]
# Out:
# 'In the 22nd century, a paraplegic Marine is dispatched to the moon Pandora on a unique mission, but becomes torn between following orders and protecting an alien civilization.'

# %%
movies_ds['overview']= movies_ds['overview'].apply(lambda x:x.split())

# %%
movies_ds.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview     budget  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...  237000000
# 1  [Captain, Barbossa,, long, believed, to, be, d...  300000000
# 2  [A, cryptic, message, from, Bond’s, past, send...  245000000
# 3  [Following, the, death, of, District, Attorney...  250000000
# 4  [John, Carter, is, a, war-weary,, former, mili...  260000000
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# ...

# %%
movies_ds['genres']=movies_ds['genres'].apply(lambda x:[i.replace(" ","") for i in x])
movies_ds['Keywords']=movies_ds['keywords'].apply(lambda x:[i.replace(" ","") for i in x])

movies_ds['crew']=movies_ds['crew'].apply(lambda x:[i.replace(" ","") for i in x])

# %%
movies_ds.head(20)
# Out:
#     movie_id                                        title  \
# 0      19995                                       Avatar
# 1        285     Pirates of the Caribbean: At World's End
# 2     206647                                      Spectre
# 3      49026                        The Dark Knight Rises
# 4      49529                                  John Carter
# 5        559                                 Spider-Man 3
# 6      38757                                      Tangled
# 7      99861                      Avengers: Age of Ultron
# 8        767       Harry Potter and the Half-Blood Prince
# 9     209112           Batman v Superman: Dawn of Justice
# 10      1452                             Superman Returns
# 11     10764                            Quantum of Solace
# 12        58   Pirates of the Caribbean: Dead Man's Chest
# 13     57201                              The Lone Ranger
# 14     49521                                 Man of Steel
# ...

# %%
# Convert non-list elements to lists

#This code snippet uses the isinstance function to check if each element in the specified columns is a list. If it's not a list, 
#it converts it to a single-element list. After this conversion, you can concatenate the columns without encountering the TypeError.

for column in ['overview', 'budget', 'genres', 'keywords', 'cast', 'crew']:
    movies_ds[column] = movies_ds[column].apply(lambda x: x if isinstance(x, list) else [x])

# Concatenate the columns
movies_ds['tags'] = movies_ds['overview'] + movies_ds['budget'] + movies_ds['genres'] + \
                    movies_ds['keywords'] + movies_ds['cast'] + movies_ds['crew']

# %%
movies_ds['tags'][0]
# Out:
# ['In',
#  'the',
#  '22nd',
#  'century,',
#  'a',
#  'paraplegic',
#  'Marine',
#  'is',
#  'dispatched',
#  'to',
#  'the',
#  'moon',
#  'Pandora',
#  'on',
#  'a',
#  'unique',
#  'mission,',
#  'but',
#  'becomes',
#  'torn',
#  'between',
#  'following',
#  'orders',
#  'and',
#  'protecting',
#  'an',
#  'alien',
#  'civilization.',
#  237000000,
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'ScienceFiction',
#  'culture clash',
#  'future',
#  'space war',
#  'space colony',
#  'society',
#  'space travel',
#  'futuristic',
#  'romance',
#  'space',
#  'alien',
#  'tribe',
#  'alien planet',
#  'cgi',
#  'marine',
#  'soldier',
#  'battle',
#  'love affair',
#  'anti war',
#  'power relations',
#  'mind and soul',
#  '3d',
#  'Sam Worthington',
#  'JamesCameron']

# %%
new_df= movies_ds[['movie_id','title','tags']]

# %%
new_df.head(10)
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
# 5       559                              Spider-Man 3
# 6     38757                                   Tangled
# 7     99861                   Avengers: Age of Ultron
# 8       767    Harry Potter and the Half-Blood Prince
# 9    209112        Batman v Superman: Dawn of Justice
#
#                                                 tags
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
# 3  [Following, the, death, of, District, Attorney...
# 4  [John, Carter, is, a, war-weary,, former, mili...
# ...

# %%
new_df['tags']= new_df['tags'].apply(lambda x:' '.join(map(str,x)))
# Out:
# C:\Users\elbhb\AppData\Local\Temp\ipykernel_15288\1753970157.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags']= new_df['tags'].apply(lambda x:' '.join(map(str,x)))

# %%
new_df.head(10)
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
# 5       559                              Spider-Man 3
# 6     38757                                   Tangled
# 7     99861                   Avengers: Age of Ultron
# 8       767    Harry Potter and the Half-Blood Prince
# 9    209112        Batman v Superman: Dawn of Justice
#
#                                                 tags
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
# ...

# %%
new_df['tags'][0]
# Out:
# 'In the 22nd century, a paraplegic Marine is dispatched to the moon Pandora on a unique mission, but becomes torn between following orders and protecting an alien civilization. 237000000 Action Adventure Fantasy ScienceFiction culture clash future space war space colony society space travel futuristic romance space alien tribe alien planet cgi marine soldier battle love affair anti war power relations mind and soul 3d Sam Worthington JamesCameron'

# %%
new_df['tags']=new_df['tags'].apply(lambda X:X.lower())
# Out:
# C:\Users\elbhb\AppData\Local\Temp\ipykernel_15288\4064007771.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags']=new_df['tags'].apply(lambda X:X.lower())

# %%
new_df.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 tags
# 0  in the 22nd century, a paraplegic marine is di...
# 1  captain barbossa, long believed to be dead, ha...
# 2  a cryptic message from bond’s past sends him o...
# 3  following the death of district attorney harve...
# 4  john carter is a war-weary, former military ca...

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv= CountVectorizer(max_features= 5000, stop_words='english')

# %%
cv.fit_transform(new_df['tags']).toarray().shape
# Out:
# (4806, 5000)

# %%
vectors = cv.fit_transform(new_df['tags']).toarray()

# %%
vectors[0]
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
import nltk

# %%
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

# %%
def stem(text):
    y=[]
    for i in text.split():
        y.append(ps.stem(i))
    return " ".join(y)

# %%
new_df['tags']= new_df['tags'].apply(stem)
# Out:
# C:\Users\elbhb\AppData\Local\Temp\ipykernel_15288\3021978705.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags']= new_df['tags'].apply(stem)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
cosine_similarity(vectors)
# Out:
# array([[1.        , 0.0761387 , 0.03549985, ..., 0.03405026, 0.05937394,
#         0.        ],
#        [0.0761387 , 1.        , 0.04662524, ..., 0.04472136, 0.        ,
#         0.        ],
#        [0.03549985, 0.04662524, 1.        , ..., 0.02085144, 0.02423931,
#         0.        ],
#        ...,
#        [0.03405026, 0.04472136, 0.02085144, ..., 1.        , 0.06974858,
#         0.03779645],
#        [0.05937394, 0.        , 0.02423931, ..., 0.06974858, 1.        ,
#         0.04393748],
#        [0.        , 0.        , 0.        , ..., 0.03779645, 0.04393748,
#         1.        ]])

# %%
cosine_similarity(vectors).shape
# Out:
# (4806, 4806)

# %%
similarity = cosine_similarity(vectors)

# %%
similarity[0]
# Out:
# array([1.        , 0.0761387 , 0.03549985, ..., 0.03405026, 0.05937394,
#        0.        ])

# %%
similarity[0].shape
# Out:
# (4806,)

# %%
sorted(list(enumerate(similarity[0])),reverse= True, key=lambda x:x[1])[1:6]
# Out:
# [(1537, 0.4361924373917497),
#  (2409, 0.4343553801592561),
#  (373, 0.41011244760386617),
#  (4336, 0.406302254164471),
#  (3162, 0.4057971014492754)]

# %%
def recommend(movie):
    movie_index = new_df[new_df['title']==movie].index[0]
    distances = similarity[movie_index]
    movies_list = sorted(list(enumerate(distances)),reverse= True, key=lambda x:x[1])[1:6]
    
    for i in movies_list:
        print(new_df.iloc[i[0]].title)

# %%
recommend('Avatar')
# Out:
# Moonraker
# Aliens
# Mission to Mars
# Silent Running
# Alien

# %%
recommend('Iron Man')
# Out:
# Iron Man 3
# Iron Man 2
# Avengers: Age of Ultron
# The Avengers
# Captain America: Civil War

# %%
recommend('Liar Liar')
# Out:
# 13 Going on 30
# Heartbreakers
# Pinocchio
# That's My Boy
# Ted

# %%
recommend('Captain America: Civil War')
# Out:
# Iron Man 3
# Captain America: The First Avenger
# Avengers: Age of Ultron
# Captain America: The Winter Soldier
# Ant-Man

# %%
recommend('Mission to Mars')
# Out:
# Gravity
# Aliens
# Avatar
# Silent Running
# Moonraker

# %%
recommend('Aliens')
# Out:
# Alien³
# Alien
# Avatar
# Mission to Mars
# Planet of the Apes

# %%
recommend('Gravity')
# Out:
# Moonraker
# Silent Running
# Spaceballs
# Mission to Mars
# Lost in Space

# %%
recommend('Ted')
# Out:
# Ted 2
# The Revenant
# Into the Grizzly Maze
# Ernest & Celestine
# Toy Story 3

# %%
import streamlit as st

def main():
    st.title("My Python Script UI")

    # Add UI components
    user_input = st.text_input("Enter some text:", "Type here...")
    result = process_text(user_input)

    # Display the result
    st.write("Result:", result)

def process_text(text):
    # Modify this function to perform the desired processing on the input text
    return text.upper()

if _name_ == "_main_":
    main()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[67], line 17
#      13 def process_text(text):
#      14     # Modify this function to perform the desired processing on the input text
#      15     return text.upper()
# ---> 17 if _name_ == "_main_":
#      18     main()
#
# NameError: name '_name_' is not defined

# %%
x = input ("Enter a Film ")
recommend(x)
